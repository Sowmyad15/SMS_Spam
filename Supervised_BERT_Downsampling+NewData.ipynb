# %% [markdown]
# <a href="https://colab.research.google.com/github/Sowmyad15/SMS_Spam/blob/main/Supervised_BERT_Downsampling%2BNewData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from transformers import BertTokenizer, BertModel
from sklearn.metrics import silhouette_score

# %%
df=pd.read_csv('/content/spam.csv',encoding='latin-1')
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
df = df.drop(labels = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis = 1)
df.columns = ["label", "message"]
df['label_num']=df['label'].map({
    'ham':0,
    'spam':1
})
df.head()
# Out:
#   label                                            message  label_num
# 0   ham  Go until jurong point, crazy.. Available only ...          0
# 1   ham                      Ok lar... Joking wif u oni...          0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...          1
# 3   ham  U dun say so early hor... U c already then say...          0
# 4   ham  Nah I don't think he goes to usf, he lives aro...          0

# %%
df_spam = df[df['label']=='spam']

df_ham = df[df['label']=='ham']

print("Ham Dataset Shape:", df_ham.shape)

print("Spam Dataset Shape:", df_spam.shape)
# Out:
# Ham Dataset Shape: (4825, 3)
# Spam Dataset Shape: (747, 3)

# %%
df_ham_downsampled = df_ham.sample(df_spam.shape[0])
df_ham_downsampled.shape
# Out:
# (747, 3)

# %%
df= pd.concat([df_spam , df_ham_downsampled])

# %%
df['label_num'].value_counts()
# Out:
# 1    747
# 0    747
# Name: label_num, dtype: int64

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def preprocess(text):
    # remove stop words and lemmatize the text
    doc = nlp(text)
    filtered_tokens = []
    for token in doc:
        if token.is_stop or token.is_punct:
            continue
        filtered_tokens.append(token.lemma_)

    return " ".join(filtered_tokens)
df['preprocessed_txt'] = df['message'].apply(preprocess)
df.head()
# Out:
#    label                                            message  label_num  \
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...          1
# 5   spam  FreeMsg Hey there darling it's been 3 week's n...          1
# 8   spam  WINNER!! As a valued network customer you have...          1
# 9   spam  Had your mobile 11 months or more? U R entitle...          1
# 11  spam  SIX chances to win CASH! From 100 to 20,000 po...          1
#
#                                      preprocessed_txt
# 2   free entry 2 wkly comp win FA Cup final tkts 2...
# 5   FreeMsg hey darle 3 week word like fun tb ok X...
# 8   WINNER value network customer select receivea ...
# 9   mobile 11 month u r entitle update late colour...
# 11  chance win cash 100 20,000 pound txt > CSH11 s...

# %%
from sklearn.model_selection import train_test_split

# %%
import torch
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased').to(device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
def get_bert_embedding(text):
    tokens = tokenizer(text, return_tensors='pt', truncation=True, padding=True)
    with torch.no_grad():
        output = model(**tokens.to(device))
    embeddings = output.last_hidden_state.mean(dim=1).cpu().numpy()
    return embeddings

# %%
df['bert_embedding'] = df['preprocessed_txt'].apply(get_bert_embedding)

# %%
X = np.vstack(df['bert_embedding'].to_numpy())

# %%
X
# Out:
# array([[ 0.06960295, -0.02238685,  0.67938733, ..., -0.05759511,
#         -0.0646834 ,  0.28856483],
#        [ 0.156755  ,  0.07545407,  0.7172379 , ..., -0.24080218,
#          0.03223718,  0.19361259],
#        [ 0.08151105,  0.03403788,  0.38506815, ..., -0.28555986,
#         -0.09771109,  0.2225598 ],
#        ...,
#        [ 0.04522947, -0.22216032,  0.34793878, ..., -0.47828776,
#         -0.16283353, -0.17768295],
#        [ 0.02013914, -0.0156334 ,  0.6282156 , ..., -0.29702237,
#         -0.03569462,  0.11736424],
#        [-0.19432424, -0.07573154,  0.31005594, ..., -0.05999246,
#          0.21722272,  0.28399855]], dtype=float32)

# %%
len(X)
# Out:
# 1494

# %%
pca = PCA(n_components=2)
reduced_embeddings = pca.fit_transform(X)

# %%
reduced_embeddings
# Out:
# array([[-2.3655047 , -0.10232036],
#        [-1.1375103 ,  1.643174  ],
#        [-2.400083  , -1.3055172 ],
#        ...,
#        [ 0.28541926,  1.2282026 ],
#        [ 1.5622097 ,  3.4362025 ],
#        [ 1.1871897 , -0.05216183]], dtype=float32)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    reduced_embeddings,
    df.label_num,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report


lr=LogisticRegression(class_weight='balanced')
lr.fit(X_train,y_train)

pred=lr.predict(X_test)

accuracy=accuracy_score(y_test,pred)
report=classification_report(y_test,pred)

print(f'Accuracy: {accuracy}\nClassification Report:\n{report}')

from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

conf_matrix = confusion_matrix(y_test, pred)

print(f'Confusion Matrix:\n{conf_matrix}')
# Out:
# Accuracy: 0.959866220735786
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       154
#            1       0.96      0.96      0.96       145
#
#     accuracy                           0.96       299
#    macro avg       0.96      0.96      0.96       299
# weighted avg       0.96      0.96      0.96       299
#
# Confusion Matrix:
# [[148   6]
#  [  6 139]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cbar=True, annot_kws={"size": 14})
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# # New Data

# %%
sample=pd.read_csv("/content/new.csv.csv",encoding="latin-1")
sample.head()

sample['label_num']=sample['Label'].map({
    'ham':0,
    'spam':1
})

sample['bert_embedding'] = sample['Message'].apply(get_bert_embedding)

X = np.vstack(sample['bert_embedding'].to_numpy())
pca = PCA(n_components=2)
reduced_embeddings = pca.fit_transform(X)

pred=lr.predict(reduced_embeddings)

accuracy=accuracy_score(sample['label_num'],pred)
report=classification_report(sample['label_num'],pred)

print(f'Accuracy: {accuracy}\nClassification Report:\n{report}')

from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

conf_matrix = confusion_matrix(sample['label_num'], pred)

print(f'Confusion Matrix:\n{conf_matrix}')
# Out:
# Accuracy: 0.8369565217391305
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.68      0.78        77
#            1       0.80      0.95      0.87       107
#
#     accuracy                           0.84       184
#    macro avg       0.86      0.81      0.82       184
# weighted avg       0.85      0.84      0.83       184
#
# Confusion Matrix:
# [[ 52  25]
#  [  5 102]]
